# %%
# importrequired libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# set the initial parameters

alpha = 1.
beta = 2.
gamma = 0.5
delta = 0.5

#define the time stepping scheme - euler forward

def euler_step(u, f, dt):
    return u + dt * f(u)


# define the function that represents the Lotka-Volterra equations

def f(u):
    x = u[0]
    y = u[1]
    return np.array([x*(alpha - beta*y), -y*(gamma - delta*x)])

# %%
# set time-increment and discretize the time

T  = 200.0                           # final time
dt = 0.01                           # set time-increment
N  = int(T/dt) + 1                # set the initial parameters

alpha = 1.
beta = 2.
gamma = 0.5
delta = 0.5

#define the time stepping scheme - euler forward

def euler_step(u, f, dt):
    return u + dt * f(u)


# define the function that represents the Lotka-Volterra equations

def f(u):
    x = u[0]
    y = u[1]
    return np.array([x*(alpha - beta*y), -y*(gamma - delta*x)])  # number of time-steps
x0 = 10.
y0 = 1.
t0 = 0.

# set initial conditions

u_euler = np.empty((N, 2))

# initialize the array containing the solution for each time-step

u_euler[0] = np.array([x0, y0])

# use a for loop to call the function rk2_step()

for n in range(N-1):
    
    u_euler[n+1] = euler_step(u_euler[n], f, dt)

# %%
time = np.linspace(0.0, T,N)
x_euler = u_euler[:,0]
y_euler = u_euler[:,1]

# %%
plt.plot(time, x_euler, label = 'prey ')
plt.plot(time, y_euler, label = 'predator')
plt.legend(loc='upper right')
#labels
plt.xlabel("time")
plt.ylabel("number of each species")
#title
plt.title("predator prey model")
# Out:
# Text(0.5,1,'predator prey model')
